# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from scipy import stats

# %%
card=pd.read_csv("cardio.csv")
card
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
sns.relplot(x='Education',y='Income',data=card)

# %%
sns.relplot(x='Education',y='Income',hue='Age',data=card)

# %%
sns.relplot(x='Age',y='Income',hue='Fitness',data=card)

# %%
sns.relplot(x='Age',y='Fitness',hue='Income',data=card)

# %%
sns.relplot(x='Age',y='Fitness',size='Income',data=card)

# %%
sns.catplot(x='Product', y='Age', data=card)

# %%
sns.catplot(x='Product', y='Age',jitter=False, data=card)

# %%
sns.catplot(x='Product', y='Age',hue='Education', data=card)

# %%
sns.catplot(x='Product', y='Age',hue='Gender', data=card)

# %%
sns.catplot(x='Product', y='Age',hue='MaritalStatus', data=card)

# %%
sns.catplot(x='Product', y='Age',hue='MaritalStatus',kind='swarm', data=card)

# %%
sns.catplot(x='Education', y='Income',kind='box', data=card)

# %%
sns.catplot(x='Education', y='Income',hue='MaritalStatus',kind='box', data=card)

# %%
sns.catplot(x='Product', y='Income',jitter=False, data=card)

# %%
sns.catplot(x='Usage', y='Income',jitter=False, data=card)

# %%
sns.catplot(x='MaritalStatus',y='Income',kind='bar',hue='Gender',data=card)

# %%
sns.catplot(x='MaritalStatus',y='Education',kind='bar',hue='Gender',data=card)

# %%
sns.catplot(x='MaritalStatus',y='Income',kind='swarm',hue='Gender',col='Product',data=card)
